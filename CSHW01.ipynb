# %% [markdown]
# ## 1.2.14

# %% [markdown]
# WordCount
#   Input: text
# 1 ) total count <- 0
# 2 ) repeat for each sentence in the text
# 3 )    count <- spaces add +1
# 4 )    add count to total count

# %% [markdown]
# ## 1.2.15

# %% [markdown]
#  SentenceCount
#    Input: text
# 1 ) total count <- 0
# 2 ) repeat for every sentence in the text
# 3 )    count <- periods, questions marks, exclamation marks
# 4 )    add count to total count

# %% [markdown]
# ## 1.3.7a

# %%
temperature = -3
windChill = 13
windChillTemperatures = 13.12 + 0.6215 * temperature + (0.3965 * temperature - 11.37) * windChill **0.16
windChillTemperatures
type(windChillTemperatures)
int(windChillTemperatures)
print('The wind chill temperatures in North America is ' + str(round(windChillTemperatures)) + ' degrees Celsius.')
# Out:
# The wind chill temperatures in North America is -8 degrees Celsius.

# %% [markdown]
# ## 1.3.8

# %%
left = right
right = left
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 left = right
#       2 right = left
#
# NameError: name 'right' is not defined

# %% [markdown]
# The variable 'right' was not defined or assigned a value -> need to define any variable before refering to it

# %%
right = 2
left = 3
temp = left
left = right
right = temp
