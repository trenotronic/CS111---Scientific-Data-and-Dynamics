# %% [markdown]
# Tren Meckel CSHW4 9/20/23

# %% [markdown]
# ## 3.2.7

# %% [markdown]
# 3.625 -> binary
#
# 3/2 -> 1 R 1 --> 1
#
# 1/2 -> 1 R 1 --> 1
#
# 3.625 - 3 = 0.625
#
# DECIMAL
#
# |      2**-1       |    2**-2    |     2**-3     |
# |:----------------:|:-----------:|:-------------:|
# |       0.5        |     0.25    |     0.125     |
# |        1         |      0      |       1       |
# |0.625 - 05 = 0.125|  too large  |0.125-0.125 + 0|
#
# FINAL ANSWER : 11.101
#
# | 1 | 1 | . | 1 | 0 | 1 |
# |:-:|:-:|:-:|:-:|:-:|:-:|
# | 2**1 | 2**0 |  | 2**-1 | 2**-1 | 2**-3 |
# | 2 + | 1 + |  |0.5 +| 0 +| 0.125 |
#
# FINAL ANSWER : 3.625

# %% [markdown]
# ## 3.2.13

# %% [markdown]
# | a | b | not (a or b) | not a and not b |
# |:-:|:-:|:------------:|:---------------:|
# | 0 | 0 |      1       |        1        |
# | 0 | 1 |      0       |        0        |
# | 1 | 0 |      0       |        0        |
# | 1 | 1 |      0       |        0        |
#
# I noticed that the not (a or b) and the (not a) and (not b) tables are equivalent.

# %% [markdown]
# ## 3.3.7

# %% [markdown]
# c) 15 * 3 // 2 --> 22 (rounded answer down from double hash lines)
#
# d) 15 * 3 / 2 --> 22.5 (normal math arithmetic)
#
# e) 15* 3 % 2 --> 1     (remainder from modulo operator)
#
# f) 15 * 3 / 2e0 --> 22.5 (e0 is 1, normal math)

# %% [markdown]
# ## 3.3.16

# %%
number = 1.0 
for count in range(10):
    number = number - 0.1
print(number)
# Out:
# 1.3877787807814457e-16

# %% [markdown]
# The final value of the number is 1.3877... etc when the answer should be 0. The answer is incorrect because as the computer converted the decimal numbers into binary float notation, the computations are performed but it leaves room for small
# errors which happened in the code and as the computer went through the loop, the errors got progressively more promient in the code and final answer.
